# %%
import dash
import dash_core_components as dcc
import dash_html_components as html

import numpy as np
from sklearn.datasets import make_swiss_roll, make_blobs
from sklearn import decomposition
from sklearn.manifold import TSNE
import pandas as pd

# %%
## Data generator functions
def generate_gaussian_blobs_different(n_samples, centers, cluster_std = 1.5):
    X, Y = make_blobs(n_samples=n_samples, 
                      centers = centers, 
                      n_features=24, 
                      random_state=6,
                     cluster_std = cluster_std,
                        center_box=(-8.0, 8.0))
    
    Y = list(Y.astype(str))
    Y = list(map(lambda x: 'Cell_type_'+x, Y))
    return X, Y


X_1, Y_1 = generate_gaussian_blobs_different(200, 2, 0.6)

# %%
app = dash.Dash()

app.layout = html.Div(
    
    dcc.Graph(
        id='example',
        figure={
            'data':[
                {'x': X_1[:,0], 'y': X_1[:,0]*0, 
                 'type': 'scatter', 
                 'mode': 'lines+text',
                 'line':dict(color = 'rgb(0, 0, 0)', width= 1),
                  'showlegend': False},
                {'x':X_1[:,0], 'y':X_1[:,0]*0, 'color':Y_1, 'width':1150, "height":400}
                
                    ],
            'layout': {'plot_bgcolor': 'rgba(0, 0, 0, 0)',
                       'paper_bgcolor': 'rgba(0, 0, 0, 0)',
            }
        })
    
)


if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_renderer/react@16.8.6.min.js?v=1.1.2&m=1576595738 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_renderer/prop-types@15.7.2.min.js?v=1.1.2&m=1576595738 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_renderer/react-dom@16.8.6.min.js?v=1.1.2&m=1576595738 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_html_components/dash_html_components.min.js?v=1.0.1&m=1576596177 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_core_components/highlight.pack.js?v=1.3.1&m=1576595950 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_renderer/dash_renderer.min.js?v=1.1.2&m=1576595738 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_core_components/dash_core_components.min.js?v=1.3.1&m=1576595950 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:58] "GET /_dash-component-suites/dash_core_components/plotly-1.50.1.min.js?v=1.3.1&m=1576595950 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:59] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2020 15:04:59] "GET /_dash-dependencies HTTP/1.1" 200 -

# %%
fig = px.scatter(x=X_1[:,0], y=X_1[:,0]*0, color = Y_1, width=1150, height=400)

axis = go.Scatter(x=[min(X_1[:,0]), max(X_1[:,0])+ 0.5 ], y=[-0.01,-0.01], 
                  mode = 'lines+text' , 
                  line = dict(color = 'rgb(0, 0, 0)', width= 1),
                  showlegend=False,
                  )
fig.update_traces(marker=dict(size=4))

fig.update_yaxes(range=[-0.5,0.5])

fig.update_xaxes(showticklabels=False)

fig.update_layout(plot_bgcolor = 'rgba(0, 0, 0, 0)',
                  paper_bgcolor= 'rgba(0, 0, 0, 0)',
                  showlegend=True,
                  annotations=[
                    dict(x=0.5, y=0.4,
                        showarrow=False,
                        text="Gene expression",
                        xref="paper",
                        yref="paper"),  
                    dict(x=1, y=0.45,
                        showarrow=False,
                        text="High",
                        xref="paper",
                        yref="paper"),
                    dict(x=0, y=0.45,
                        showarrow=False,
                        text="Low",
                        xref="paper",
                        yref="paper"),
                             
                              ],
                  legend=dict(x=0.85, y=1.1)
)

fig.update_xaxes(visible= False)

fig.update_yaxes(visible= False)
fig.update_traces(hovertemplate=None, hoverinfo='skip')
config={'displaylogo': False,'displayModeBar': False}


fig.add_trace(axis)
fig.show(config=config)

#fig.write_html("../plots/1d_5cells.html", config=config)
#fig.write_html("../plots/1d.html", config=config)
